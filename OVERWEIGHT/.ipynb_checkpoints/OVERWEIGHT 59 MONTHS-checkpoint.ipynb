# %%
import numpy as np 
import pandas as pd 
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
#from pandas_profiling import ProfileReport
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
#from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, r2_score
#from sklearn.pipeline import Pipeline
#from sklearn.impute import SimpleImputer
#from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
df = pd.read_csv('2018_2019_24-59mos_overweight_complete.csv')
origfeatures = df.columns
print ("original features count", len(origfeatures))
print ("original features", origfeatures)
df.head()
# Out:
# original features count 42
# original features Index(['age_child', 'agemos', 'AgeGroup', 'sex_child', 'gastation',
#        'place_delivery', 'assistd', 'typeofd', 'pregtype', 'bw_grams',
#        'bw_status', 'ethnicity', 'age_mom', 'agegroup_mom', 'csc_mom',
#        'psccat_mom', 'educ_mom', 'occup_mom', 'work_status_mom', 'age_hh',
#        'agegroup_HH', 'sex_hh', 'educ_hh', 'psoc_hh', 'work_status_hh',
#        'urbanity', 'hhsize', 'hhsize_code', 'drinkingwater', 'recipient_4ps',
#        'toilet', 'electrct1', 'drinksafe', 'makesafe', 'wcooking', 'whands',
#        'collect', 'burn', 'composting', 'dump', 'segregate', 'overweight'],
#       dtype='object')
#    age_child  agemos  AgeGroup  sex_child  gastation  place_delivery  assistd  \
# 0          4      48         3          2          1               1        1
# 1          3      34         1          2          1               1        1
# 2          4      51         3          1          1               1        1
# 3          4      51         3          2          1               0        1
# 4          2      28         1          2          1               1        1
#
#    typeofd  pregtype  bw_grams  ...  drinksafe  makesafe  wcooking  whands  \
# 0        1         1      2400  ...          0         0         2       2
# 1        1         1      2500  ...          9         9         2       2
# 2        1         1      2500  ...          0         0         2       2
# 3        1         1      3200  ...          0         0         2       2
# 4        1         1      2800  ...          9         9         2       2
#
#    collect  burn  composting  dump  segregate  overweight
# 0        0     0           1     0          0           0
# 1        0     1           0     1          1           0
# 2        0     0           1     0          0           0
# 3        0     1           0     0          0           0
# 4        0     1           0     1          0           0
#
# [5 rows x 42 columns]

# %% [markdown]
# # FEATURE SELECTION USING CHI2

# %%
X = df.iloc[:,0:39]
y = df.iloc[:,-1]
feature = SelectKBest(score_func=chi2, k=10)
fit = feature.fit(X,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

# %%
features = pd.concat([dfcolumns,dfscores], axis = 1)
features.columns = ['Overweight','Scores']
features
# Out:
#          Overweight       Scores
# 0         age_child     1.255468
# 1            agemos     5.649619
# 2          AgeGroup     0.469263
# 3         sex_child     0.186136
# 4         gastation     0.000019
# 5    place_delivery     2.220605
# 6           assistd     1.530660
# 7           typeofd    12.835457
# 8          pregtype     0.000047
# 9          bw_grams  3832.949872
# 10        bw_status     0.061816
# 11        ethnicity    12.393160
# 12          age_mom    12.897359
# 13     agegroup_mom     0.015713
# 14          csc_mom     4.717997
# 15       psccat_mom    88.094174
# 16         educ_mom    38.793012
# 17        occup_mom    84.415602
# 18  work_status_mom    35.737287
# 19           age_hh   114.047374
# 20      agegroup_HH     5.631312
# 21           sex_hh     0.506336
# 22          educ_hh    41.258898
# 23          psoc_hh   823.665070
# 24   work_status_hh     2.358465
# 25         urbanity     0.130786
# 26           hhsize     9.175485
# 27      hhsize_code     1.666092
# 28    drinkingwater    65.795618
# 29    recipient_4ps    48.709077
# 30           toilet     1.016522
# 31        electrct1     0.723068
# 32        drinksafe   421.297297
# 33         makesafe   354.976151
# 34         wcooking   261.152392
# 35           whands   630.843135
# 36          collect    36.228581
# 37             burn    22.890440
# 38       composting    11.260159

# %%
print(features.nlargest(10, "Scores"))
# Out:
#        Overweight       Scores
# 9        bw_grams  3832.949872
# 23        psoc_hh   823.665070
# 35         whands   630.843135
# 32      drinksafe   421.297297
# 33       makesafe   354.976151
# 34       wcooking   261.152392
# 19         age_hh   114.047374
# 15     psccat_mom    88.094174
# 17      occup_mom    84.415602
# 28  drinkingwater    65.795618

# %%
data = df[["bw_grams","psoc_hh","whands","drinksafe","makesafe","wcooking",
           "age_hh","psccat_mom","occup_mom","drinkingwater","overweight"]]

# %%
data.columns
# Out:
# Index(['bw_grams', 'psoc_hh', 'whands', 'drinksafe', 'makesafe', 'wcooking',
#        'age_hh', 'psccat_mom', 'occup_mom', 'drinkingwater', 'overweight'],
#       dtype='object')

# %%
data.head()
# Out:
#    bw_grams  psoc_hh  whands  drinksafe  makesafe  wcooking  age_hh  \
# 0      2400        6       2          0         0         2      37
# 1      2500       99       2          9         9         2      54
# 2      2500        6       2          0         0         2      38
# 3      3200        6       2          0         0         2      36
# 4      2800        8       2          9         9         2      44
#
#    psccat_mom  occup_mom  drinkingwater  overweight
# 0           0         10              0           0
# 1           2         10              1           0
# 2           0          5              0           0
# 3           0          5              0           0
# 4           0         10              1           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14502 entries, 0 to 14501
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bw_grams       14502 non-null  int64
#  1   psoc_hh        14502 non-null  int64
#  2   whands         14502 non-null  int64
#  3   drinksafe      14502 non-null  int64
#  4   makesafe       14502 non-null  int64
#  5   wcooking       14502 non-null  int64
#  6   age_hh         14502 non-null  int64
#  7   psccat_mom     14502 non-null  int64
#  8   occup_mom      14502 non-null  int64
#  9   drinkingwater  14502 non-null  int64
#  10  overweight     14502 non-null  int64
# dtypes: int64(11)
# memory usage: 1.2 MB

# %%
display("Total number of of Duplicates present in data: %s" %data.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 311'

# %%
data = data.drop_duplicates()

# %%
display("Total number of of Duplicates present in data: %s" %data.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 0'

# %%
#checking correlation between the variables
plt.figure(figsize=(10, 5))
sns.heatmap(data.corr(), annot=True);
plt.title('Correlation Matrix', fontsize=20);

# %%
overweight_label = data.overweight.value_counts()
plt.figure(figsize=(8, 5))
sns.barplot(overweight_label.index, overweight_label);
plt.xlabel('overweight', fontsize=20);
plt.ylabel('Count', fontsize=20)
# Out:
# C:\Users\Supervisor\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %%
data['overweight'].value_counts()
# Out:
# 0    13688
# 1      503
# Name: overweight, dtype: int64

# %%
Final = df[["bw_grams","psoc_hh","whands","drinksafe","makesafe","wcooking",
           "age_hh","psccat_mom","occup_mom","drinkingwater"]]
Target =df['overweight']

# %%
Final.head()
# Out:
#    bw_grams  psoc_hh  whands  drinksafe  makesafe  wcooking  age_hh  \
# 0      2400        6       2          0         0         2      37
# 1      2500       99       2          9         9         2      54
# 2      2500        6       2          0         0         2      38
# 3      3200        6       2          0         0         2      36
# 4      2800        8       2          9         9         2      44
#
#    psccat_mom  occup_mom  drinkingwater
# 0           0         10              0
# 1           2         10              1
# 2           0          5              0
# 3           0          5              0
# 4           0         10              1

# %%
Final.head()
# Out:
#    bw_grams  psoc_hh  whands  drinksafe  makesafe  wcooking  age_hh  \
# 0      2400        6       2          0         0         2      37
# 1      2500       99       2          9         9         2      54
# 2      2500        6       2          0         0         2      38
# 3      3200        6       2          0         0         2      36
# 4      2800        8       2          9         9         2      44
#
#    psccat_mom  occup_mom  drinkingwater
# 0           0         10              0
# 1           2         10              1
# 2           0          5              0
# 3           0          5              0
# 4           0         10              1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Final,Target,test_size = 0.2, random_state=42)

# %%
Logistic = LogisticRegression()
Log_pred = Logistic.fit(X_train,y_train)
log_pred = Log_pred.predict(X_test)

ascore = accuracy_score(log_pred,y_test)
pred_prob_log_reg = Log_pred.predict_proba(X_test)

print("Training score: {:.3f}".format(Log_pred.score(X_train, y_train)))
print("Accuracy score :",ascore)
# Out:
# Training score: 0.964
# Accuracy score : 0.9696656325405033
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
log_model= LogisticRegression()
log_model.fit(X_train,y_train)
logistic_pred= log_model.predict(X_test)
from sklearn import metrics

log_cm = metrics.confusion_matrix(y_test, logistic_pred)
plt.figure(figsize=(6,5))
sns.heatmap(log_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,logistic_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,logistic_pred))
# Out:
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2813
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.97      2901
#    macro avg       0.48      0.50      0.49      2901
# weighted avg       0.94      0.97      0.95      2901
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rforest = RandomForestClassifier(n_estimators=30, max_features=3, random_state=0)
r_pred = rforest.fit(X_train,y_train)
rf_pred = r_pred.predict(X_test)
print("Training score: {:.3f}".format(r_pred.score(X_train, y_train)))
print("Accuracy score: ",accuracy_score(rf_pred,y_test))

rforest_cm = metrics.confusion_matrix(y_test, rf_pred)
plt.figure(figsize=(6,5))
sns.heatmap(rforest_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,rf_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,rf_pred))
# Out:
# Training score: 0.996
# Accuracy score:  0.9648397104446742
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2813
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.96      2901
#    macro avg       0.48      0.50      0.49      2901
# weighted avg       0.94      0.96      0.95      2901

# %%
rf_model=RandomForestClassifier(random_state=0)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
from sklearn import metrics

rf_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(rf_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2813
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.97      2901
#    macro avg       0.48      0.50      0.49      2901
# weighted avg       0.94      0.97      0.95      2901

# %%
gbr = GradientBoostingClassifier(n_estimators=100, max_depth=10, max_features=3, random_state=0).fit(X_train, y_train)
gbr_pred= gbr.score(X_test, y_test)

gbr_train_accuracy =gbr.score(X_train,y_train)
gbr_accuracy = gbr.score(X_test,y_test)
pred_prob_gbr = gbr.predict_proba(X_test)


print("Training score: {:.3f}".format(gbr.score(X_train, y_train)))
print("Test score: {:.3f}".format(gbr.score(X_test, y_test)))
# Out:
# Training score: 0.998
# Test score: 0.965

# %%
gbr_model=GradientBoostingClassifier(random_state=0)
gbr_test = gbr_model.fit(X_train,y_train)
y_pred_gbr=gbr_test.predict(X_test)
from sklearn import metrics
gbr_pred_randomstate= gbr.score(X_test, y_test)

gbr_cm = metrics.confusion_matrix(y_test, y_pred_gbr)
plt.figure(figsize=(6,5))
sns.heatmap(gbr_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred_gbr))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred_gbr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2813
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.97      2901
#    macro avg       0.48      0.50      0.49      2901
# weighted avg       0.94      0.97      0.95      2901

# %%
from sklearn.utils import resample

#Separate Target Classes
df_1 = data[data.overweight==0]
df_2 = data[data.overweight==1]

# Upsample minority class
df_2_upsampled = resample(df_2, 
                                 replace=True,     # sample with replacement
                                 n_samples=13688,    # to match majority class
                                 random_state=123) # reproducible results

# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_1, df_2_upsampled])
 
# Display new class counts
df_upsampled.overweight.value_counts()
df_upsampled.reset_index(drop=True)
# Out:
#        bw_grams  psoc_hh  whands  drinksafe  makesafe  wcooking  age_hh  \
# 0          2400        6       2          0         0         2      37
# 1          2500       99       2          9         9         2      54
# 2          2500        6       2          0         0         2      38
# 3          3200        6       2          0         0         2      36
# 4          2800        8       2          9         9         2      44
# ...         ...      ...     ...        ...       ...       ...     ...
# 27371      2200        9       1          9         9         1      61
# 27372      3600        5      11          0         0        11      36
# 27373      3800        6       5          0         0         5      28
# 27374      3600        8       1          9         9         1      29
# 27375      3100        6       4          0         0         4      40
#
#        psccat_mom  occup_mom  drinkingwater  overweight
# 0               0         10              0           0
# 1               2         10              1           0
# 2               0          5              0           0
# 3               0          5              0           0
# 4               0         10              1           0
# ...           ...        ...            ...         ...
# 27371           2         10              1           1
# 27372           0          5              1           1
# 27373           0         10              0           1
# 27374           0          9              1           1
# 27375           0         10              0           1
#
# [27376 rows x 11 columns]

# %%
df_upsampled['overweight'].value_counts()
# Out:
# 0    13688
# 1    13688
# Name: overweight, dtype: int64

# %%
overweight_label = df_upsampled.overweight.value_counts()
plt.figure(figsize=(10, 5))
sns.barplot(overweight_label.index, overweight_label);
plt.xlabel('overweight', fontsize=20);
plt.ylabel('Count', fontsize=20)
# Out:
# C:\Users\Supervisor\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %%
df_upsampled.columns
# Out:
# Index(['bw_grams', 'psoc_hh', 'whands', 'drinksafe', 'makesafe', 'wcooking',
#        'age_hh', 'psccat_mom', 'occup_mom', 'drinkingwater', 'overweight'],
#       dtype='object')

# %%
df_upsampled['overweight'].value_counts()
# Out:
# 0    13688
# 1    13688
# Name: overweight, dtype: int64

# %%
Final = df_upsampled[["bw_grams","psoc_hh","whands","drinksafe","makesafe","wcooking",
           "age_hh","psccat_mom","occup_mom","drinkingwater"]]
Target =df_upsampled['overweight']

# %%
Final.head()
# Out:
#    bw_grams  psoc_hh  whands  drinksafe  makesafe  wcooking  age_hh  \
# 0      2400        6       2          0         0         2      37
# 1      2500       99       2          9         9         2      54
# 2      2500        6       2          0         0         2      38
# 3      3200        6       2          0         0         2      36
# 4      2800        8       2          9         9         2      44
#
#    psccat_mom  occup_mom  drinkingwater
# 0           0         10              0
# 1           2         10              1
# 2           0          5              0
# 3           0          5              0
# 4           0         10              1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Final,Target,test_size = 0.2, random_state=42)

# %%
Logistic = LogisticRegression()
Log_pred = Logistic.fit(X_train,y_train)
log_pred = Log_pred.predict(X_test)

ascore = accuracy_score(log_pred,y_test)
pred_prob_log_reg = Log_pred.predict_proba(X_test)

print("Training score: {:.3f}".format(Log_pred.score(X_train, y_train)))
print("Accuracy score :",ascore)
# Out:
# Training score: 0.637
# Accuracy score : 0.6376917457998539
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
rforest = RandomForestClassifier(n_estimators=30, max_features=3, random_state=0)
r_pred = rforest.fit(X_train,y_train)
rf_pred = r_pred.predict(X_test)
print("Training score: {:.3f}".format(r_pred.score(X_train, y_train)))
print("Accuracy score: ",accuracy_score(rf_pred,y_test))

pred_prob_rf = r_pred.predict_proba(X_test)
# Out:
# Training score: 0.999
# Accuracy score:  0.9919649379108838

# %%
rf_model=RandomForestClassifier(random_state=0)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
from sklearn import metrics

rf_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(rf_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
rf_acc = accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      2758
#            1       0.98      1.00      0.99      2718
#
#     accuracy                           0.99      5476
#    macro avg       0.99      0.99      0.99      5476
# weighted avg       0.99      0.99      0.99      5476

# %%
gbr = GradientBoostingClassifier(n_estimators=100, max_depth=10, max_features=3, random_state=0).fit(X_train, y_train)
gbr_pred= gbr.score(X_test, y_test)

gbr_train_accuracy =gbr.score(X_train,y_train)
gbr_accuracy = gbr.score(X_test,y_test)
pred_prob_gbr = gbr.predict_proba(X_test)


print("Training score: {:.3f}".format(gbr.score(X_train, y_train)))
print("Test score: {:.3f}".format(gbr.score(X_test, y_test)))
# Out:
# Training score: 0.994
# Test score: 0.983

# %%
gbr_model=GradientBoostingClassifier(random_state=0)
gbr_test = gbr_model.fit(X_train,y_train)
y_pred_gbr=gbr_test.predict(X_test)
from sklearn import metrics
gbr_pred_randomstate= gbr.score(X_test, y_test)

gbr_cm = metrics.confusion_matrix(y_test, y_pred_gbr)
plt.figure(figsize=(6,5))
sns.heatmap(gbr_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred_gbr))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred_gbr))
gbr_acc=accuracy_score(y_test,y_pred_gbr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.68      0.71      2758
#            1       0.70      0.75      0.72      2718
#
#     accuracy                           0.72      5476
#    macro avg       0.72      0.72      0.72      5476
# weighted avg       0.72      0.72      0.72      5476

# %%
svc_model=SVC(random_state=0)
svc_model.fit(X_train,y_train)
y_pred=svc_model.predict(X_test)
from sklearn import metrics

svc_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(svc_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
svc_acc =accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.72      0.62      2758
#            1       0.58      0.39      0.46      2718
#
#     accuracy                           0.56      5476
#    macro avg       0.56      0.55      0.54      5476
# weighted avg       0.56      0.56      0.54      5476

# %%
k_range = range(1,11)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    scores.append(knn.score(X_test, y_test))

plt.xlabel('k')
plt.ylabel('accuracy')
plt.scatter(k_range, scores)
plt.vlines(k_range,0, scores, linestyle="dashed", colors='maroon')
plt.ylim(0.70,0.99)
plt.xticks([i for i in range(1,11)]);

# %%
knn_model=KNeighborsClassifier(n_neighbors = 2)
knn_model.fit(X_train,y_train)
y_pred_knn=knn_model.predict(X_test)
from sklearn import metrics

knn_cm = metrics.confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(6,5))
sns.heatmap(knn_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred_knn))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred_knn))
pred_prob_knn = gbr.predict_proba(X_test)
knn_pred_acc = accuracy_score(y_test,y_pred_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98      2758
#            1       0.95      1.00      0.98      2718
#
#     accuracy                           0.98      5476
#    macro avg       0.98      0.98      0.98      5476
# weighted avg       0.98      0.98      0.98      5476

# %%
import xgboost as xgb
XB = xgb.XGBClassifier()
XB.fit(X_train,y_train)
XB_pred = XB.score(X_test,y_test)
XB_train_accuracy = XB.score(X_train,y_train)
pred_prob_XB = XB.predict_proba(X_test)

print("Training accuracy = ",XB.score(X_train,y_train))
#Print Test Accuracy
XB_accuracy = XB.score(X_test,y_test)
print("Testing accuracy = ",XB.score(X_test,y_test))
# Out:
# Training accuracy =  0.969041095890411
# Testing accuracy =  0.9523374726077429

# %%
XB_model=xgb.XGBClassifier()
XB_model.fit(X_train,y_train)
y_pred=XB_model.predict(X_test)
from sklearn import metrics

XB_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(XB_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
XG_BOOST = accuracy_score(y_test,y_pred)
XG_BOOST
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      2758
#            1       0.92      1.00      0.95      2718
#
#     accuracy                           0.95      5476
#    macro avg       0.96      0.95      0.95      5476
# weighted avg       0.96      0.95      0.95      5476
# 0.9523374726077429

# %%
#2. Gaussian Naive Bayes Classifier
#t0 = time()
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()
gnb.fit(X_train,y_train)
gnb_pred = gnb.score(X_test,y_test)
gnb_train_accuracy = gnb.score(X_train,y_train)
pred_prob_gnb = gnb.predict_proba(X_test)
gnb_acc = gnb.predict(X_test)

print("Training accuracy = ",gnb.score(X_train,y_train))
#Print Test Accuracy
gnb_accuracy = gnb.score(X_test,y_test)
print("Testing accuracy = ",gnb.score(X_test,y_test))
gnb_acc2 = accuracy_score(gnb_acc,y_test)
gnb_acc2
# Out:
# Training accuracy =  0.6358447488584474
# Testing accuracy =  0.6360482103725347
# 0.6360482103725347

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob_log_reg[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob_rf[:,1], pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_test, pred_prob_gbr[:,1], pos_label=1)
fpr4, tpr4, thresh4 = roc_curve(y_test, pred_prob_knn[:,1], pos_label=1)
fpr5, tpr5, thresh5 = roc_curve(y_test, pred_prob_XB[:,1], pos_label=1)
fpr6, tpr6, thresh6 = roc_curve(y_test, pred_prob_gnb[:,1], pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, pred_prob_log_reg[:,1],multi_class='ovr')
auc_score2 = roc_auc_score(y_test, pred_prob_rf[:,1],multi_class='ovr')
auc_score3 = roc_auc_score(y_test, pred_prob_gbr[:,1],multi_class='ovr')
auc_score4 = roc_auc_score(y_test, pred_prob_knn[:,1],multi_class='ovr')
auc_score5 = roc_auc_score(y_test, pred_prob_XB[:,1],multi_class='ovr')
auc_score6 = roc_auc_score(y_test, pred_prob_gnb[:,1],multi_class='ovr')


print(auc_score1, auc_score2,auc_score3, auc_score4,auc_score5,auc_score6)
# Out:
# 0.690522013424323 0.9994419205137933 0.9988650983078993 0.9988650983078993 0.9909494674933206 0.6833658963075376

# %%
# plot roc curves
plt.plot(fpr1, tpr1,linestyle='--',color='orange', label='Logistic Regression')
plt.plot(fpr2, tpr2,linestyle='--',color='green', label='Random Forest')
plt.plot(fpr3, tpr3, linestyle='--',color='red', label='Gradient Boosting')
plt.plot(fpr4, tpr4, linestyle='--',color='purple', label='KNN')
plt.plot(fpr5, tpr5, linestyle='--',color='cyan', label='XGBoost')
plt.plot(fpr6, tpr6, linestyle='--',color='yellow', label='Naive Bayes')

# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();

# %%
predictions_acc = { "Model": ['Logistic Regression', 'Random Forest Classifier','Gradient Boosting Classifier', 'SVC','KNierest Neighbor','Extreme Gradient Boosting', 'Naive Bayes Classifier'],
"Accuracy": [ascore,rf_acc,gbr_accuracy,svc_acc,knn_pred_acc,XG_BOOST,gnb_acc2]}

# %%
model_acc = pd.DataFrame(predictions_acc, columns=["Model", "Accuracy"])
model_acc
# Out:
#                           Model  Accuracy
# 0           Logistic Regression  0.637692
# 1      Random Forest Classifier  0.991234
# 2  Gradient Boosting Classifier  0.982652
# 3                           SVC  0.555698
# 4             KNierest Neighbor  0.975895
# 5     Extreme Gradient Boosting  0.952337
# 6        Naive Bayes Classifier  0.636048

# %%
Model_Name = ['Logistic Regression', 'Random Forest Classifier','Gradient Boosting Classifier', 'SVC','KNierest Neighbor','XBoost', 'Naive Bayes Classifier']
Accuracy = [ascore,rf_acc,gbr_accuracy,svc_acc,knn_pred_acc,XG_BOOST,gnb_acc2]

# %%
plt.figure(figsize=(15,9))
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Model')
sns.barplot(x = Accuracy,y = Model_Name)
plt.show()

# %%
y_test_pred = rf_model.predict(X_test)
print("Accuracy Score of Random Forest:",accuracy_score(y_test,y_test_pred))
# Out:
# Accuracy Score of Random Forest: 0.9912344777209642

# %%
output = pd.DataFrame({'Real_class': y_test, 'Predicted_class': y_test_pred, 'Difference': y_test-y_test_pred})
output.head(10)
# Out:
#        Real_class  Predicted_class  Difference
# 9689            0                0           0
# 5207            1                1           0
# 12089           1                1           0
# 2521            1                1           0
# 6870            0                0           0
# 6563            1                1           0
# 3917            0                0           0
# 3115            1                1           0
# 13436           0                0           0
# 7078            1                1           0

# %% [markdown]
# # Features Importance using ExtraTreeClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_)
# Out:
# [0.03833264 0.06087681 0.03254525 0.03119462 0.00589665 0.00582564
#  0.00409743 0.01656931 0.00199049 0.07261289 0.01442238 0.00829899
#  0.06240981 0.01813303 0.03424163 0.01592024 0.03373793 0.03345387
#  0.01354257 0.06208777 0.02773851 0.01849402 0.03877728 0.04885832
#  0.00917882 0.02779125 0.05140646 0.0207022  0.01175025 0.01223482
#  0.00353401 0.00455424 0.0156552  0.01891901 0.04008352 0.03654454
#  0.01515525 0.01736121 0.01507114]

# %%
f_importances = pd.Series(model.feature_importances_, index = X.columns)
f_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
data2 = df[["bw_grams","age_mom","age_hh","agemos","hhsize","psoc_hh",
             "wcooking","educ_hh","age_child","whands","overweight"]]

# %%
data2.head()
# Out:
#    bw_grams  age_mom  age_hh  agemos  hhsize  psoc_hh  wcooking  educ_hh  \
# 0      2400       33      37      48       5        6         2        3
# 1      2500       26      54      34      10       99         2        2
# 2      2500       35      38      51       5        6         2        1
# 3      3200       38      36      51       7        6         2        2
# 4      2800       43      44      28       8        8         2        1
#
#    age_child  whands  overweight
# 0          4       2           0
# 1          3       2           0
# 2          4       2           0
# 3          4       2           0
# 4          2       2           0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14502 entries, 0 to 14501
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bw_grams    14502 non-null  int64
#  1   age_mom     14502 non-null  int64
#  2   age_hh      14502 non-null  int64
#  3   agemos      14502 non-null  int64
#  4   hhsize      14502 non-null  int64
#  5   psoc_hh     14502 non-null  int64
#  6   wcooking    14502 non-null  int64
#  7   educ_hh     14502 non-null  int64
#  8   age_child   14502 non-null  int64
#  9   whands      14502 non-null  int64
#  10  overweight  14502 non-null  int64
# dtypes: int64(11)
# memory usage: 1.2 MB

# %%
display("Total number of of Duplicates present in data: %s" %data2.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 18'

# %%
data2 = data2.drop_duplicates()

# %%
display("Total number of of Duplicates present in data: %s" %data2.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 0'

# %%
#checking correlation between the variables
plt.figure(figsize=(10, 5))
sns.heatmap(data2.corr(), annot=True);
plt.title('Correlation Matrix', fontsize=20);

# %%
overweight_label = data2.overweight.value_counts()
plt.figure(figsize=(8,5))
sns.barplot(overweight_label.index, overweight_label);
plt.xlabel('overweight', fontsize=20)
plt.ylabel('Count',fontsize=20)
# Out:
# C:\Users\Supervisor\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %%
Final2 = df[["bw_grams","age_mom","age_hh","agemos","hhsize","psoc_hh",
             "wcooking","educ_hh","age_child","whands"]]
Target2 =df['overweight']

# %%
Final2.head()
# Out:
#    bw_grams  age_mom  age_hh  agemos  hhsize  psoc_hh  wcooking  educ_hh  \
# 0      2400       33      37      48       5        6         2        3
# 1      2500       26      54      34      10       99         2        2
# 2      2500       35      38      51       5        6         2        1
# 3      3200       38      36      51       7        6         2        2
# 4      2800       43      44      28       8        8         2        1
#
#    age_child  whands
# 0          4       2
# 1          3       2
# 2          4       2
# 3          4       2
# 4          2       2

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Final2,Target2,test_size = 0.2, random_state=42)

# %%
Logistic = LogisticRegression()
Log_pred = Logistic.fit(X_train,y_train)
log_pred = Log_pred.predict(X_test)

ascore = accuracy_score(log_pred,y_test)
pred_prob_log_reg = Log_pred.predict_proba(X_test)

print("Training score: {:.3f}".format(Log_pred.score(X_train, y_train)))
print("Accuracy score :",ascore)
# Out:
# Training score: 0.964
# Accuracy score : 0.9696656325405033
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
rforest = RandomForestClassifier(n_estimators=30, max_features=3, random_state=0)
r_pred = rforest.fit(X_train,y_train)
rf_pred = r_pred.predict(X_test)
print("Training score: {:.3f}".format(r_pred.score(X_train, y_train)))
print("Accuracy score: ",accuracy_score(rf_pred,y_test))
# Out:
# Training score: 0.997
# Accuracy score:  0.9693209238193726

# %%
rf_model=RandomForestClassifier(random_state=0)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
from sklearn import metrics

rf_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(rf_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2813
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.97      2901
#    macro avg       0.48      0.50      0.49      2901
# weighted avg       0.94      0.97      0.95      2901

# %%
data2['overweight'].value_counts()
# Out:
# 0    13980
# 1      504
# Name: overweight, dtype: int64

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14484 entries, 0 to 14501
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bw_grams    14484 non-null  int64
#  1   age_mom     14484 non-null  int64
#  2   age_hh      14484 non-null  int64
#  3   agemos      14484 non-null  int64
#  4   hhsize      14484 non-null  int64
#  5   psoc_hh     14484 non-null  int64
#  6   wcooking    14484 non-null  int64
#  7   educ_hh     14484 non-null  int64
#  8   age_child   14484 non-null  int64
#  9   whands      14484 non-null  int64
#  10  overweight  14484 non-null  int64
# dtypes: int64(11)
# memory usage: 1.3 MB

# %%
data2.head()
# Out:
#    bw_grams  age_mom  age_hh  agemos  hhsize  psoc_hh  wcooking  educ_hh  \
# 0      2400       33      37      48       5        6         2        3
# 1      2500       26      54      34      10       99         2        2
# 2      2500       35      38      51       5        6         2        1
# 3      3200       38      36      51       7        6         2        2
# 4      2800       43      44      28       8        8         2        1
#
#    age_child  whands  overweight
# 0          4       2           0
# 1          3       2           0
# 2          4       2           0
# 3          4       2           0
# 4          2       2           0

# %%
from sklearn.utils import resample

# Separate Target Classes
df_1 = data2[data2.overweight==0]
df_2 = data2[data2.overweight==1]
 
# Upsample minority class
df_2_upsampled2 = resample(df_2, 
                                 replace=True,     # sample with replacement
                                 n_samples=13980,    # to match majority class
                                 random_state=123) # reproducible results

# Combine majority class with upsampled minority class
df_upsampled2 = pd.concat([df_1, df_2_upsampled2])
 
# Display new class counts
df_upsampled2.overweight.value_counts()
df_upsampled2.reset_index(drop=True)
# Out:
#        bw_grams  age_mom  age_hh  agemos  hhsize  psoc_hh  wcooking  educ_hh  \
# 0          2400       33      37      48       5        6         2        3
# 1          2500       26      54      34      10       99         2        2
# 2          2500       35      38      51       5        6         2        1
# 3          3200       38      36      51       7        6         2        2
# 4          2800       43      44      28       8        8         2        1
# ...         ...      ...     ...     ...     ...      ...       ...      ...
# 27955      3000       31      67      44       6       99         1        1
# 27956      3200       28      72      48       5       99        11        2
# 27957      2800       27      25      58       3        5         1        2
# 27958      3900       35      59      46       5        5         2        1
# 27959      3234       29      66      37       9        2        11        3
#
#        age_child  whands  overweight
# 0              4       2           0
# 1              3       2           0
# 2              4       2           0
# 3              4       2           0
# 4              2       2           0
# ...          ...     ...         ...
# 27955          4       1           1
# 27956          4      11           1
# 27957          5       1           1
# 27958          4       2           1
# 27959          3      11           1
#
# [27960 rows x 11 columns]

# %%
df_upsampled2.columns
# Out:
# Index(['bw_grams', 'age_mom', 'age_hh', 'agemos', 'hhsize', 'psoc_hh',
#        'wcooking', 'educ_hh', 'age_child', 'whands', 'overweight'],
#       dtype='object')

# %%
df_upsampled2['overweight'].value_counts()
# Out:
# 0    13980
# 1    13980
# Name: overweight, dtype: int64

# %%
Final3 = df_upsampled2[["bw_grams","age_mom","age_hh","agemos","hhsize","psoc_hh",
             "wcooking","educ_hh","age_child","whands"]]
Target3 =df_upsampled2['overweight']

# %%
Final3.head()
# Out:
#    bw_grams  age_mom  age_hh  agemos  hhsize  psoc_hh  wcooking  educ_hh  \
# 0      2400       33      37      48       5        6         2        3
# 1      2500       26      54      34      10       99         2        2
# 2      2500       35      38      51       5        6         2        1
# 3      3200       38      36      51       7        6         2        2
# 4      2800       43      44      28       8        8         2        1
#
#    age_child  whands
# 0          4       2
# 1          3       2
# 2          4       2
# 3          4       2
# 4          2       2

# %%
Target3.value_counts()
# Out:
# 0    13980
# 1    13980
# Name: overweight, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Final3,Target3,test_size = 0.2, random_state=42)

# %%
Logistic = LogisticRegression()
Log_pred = Logistic.fit(X_train,y_train)
log_pred = Log_pred.predict(X_test)

ascore = accuracy_score(log_pred,y_test)
pred_prob_log_reg = Log_pred.predict_proba(X_test)

print("Training score: {:.3f}".format(Log_pred.score(X_train, y_train)))
print("Accuracy score :",ascore)
# Out:
# Training score: 0.620
# Accuracy score : 0.6237482117310443
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
rforest = RandomForestClassifier(n_estimators=30, max_features=3, random_state=0)
r_pred = rforest.fit(X_train,y_train)
rf_pred = r_pred.predict(X_test)
print("Training score: {:.3f}".format(r_pred.score(X_train, y_train)))
print("Accuracy score: ",accuracy_score(rf_pred,y_test))

pred_prob_rf = r_pred.predict_proba(X_test)
# Out:
# Training score: 1.000
# Accuracy score:  0.9983905579399142

# %%
rf_model=RandomForestClassifier(random_state=0)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
from sklearn import metrics

rf_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(rf_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
rf_acc = accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2810
#            1       1.00      1.00      1.00      2782
#
#     accuracy                           1.00      5592
#    macro avg       1.00      1.00      1.00      5592
# weighted avg       1.00      1.00      1.00      5592

# %%
 gbr = GradientBoostingClassifier(n_estimators=100, max_depth=10, max_features=3, random_state=0).fit(X_train, y_train)
gbr_pred= gbr.score(X_test, y_test)

gbr_train_accuracy =gbr.score(X_train,y_train)
gbr_accuracy = gbr.score(X_test,y_test)
pred_prob_gbr = gbr.predict_proba(X_test)


print("Training score: {:.3f}".format(gbr.score(X_train, y_train)))
print("Test score: {:.3f}".format(gbr.score(X_test, y_test)))
# Out:
# Training score: 0.999
# Test score: 0.992

# %%
gbr_model=GradientBoostingClassifier(random_state=0)
gbr_test = gbr_model.fit(X_train,y_train)
y_pred_gbr=gbr_test.predict(X_test)
from sklearn import metrics
gbr_pred_randomstate= gbr.score(X_test, y_test)

gbr_cm = metrics.confusion_matrix(y_test, y_pred_gbr)
plt.figure(figsize=(6,5))
sns.heatmap(gbr_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred_gbr))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred_gbr))
gbr_acc=accuracy_score(y_test,y_pred_gbr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74      2810
#            1       0.73      0.78      0.76      2782
#
#     accuracy                           0.75      5592
#    macro avg       0.75      0.75      0.75      5592
# weighted avg       0.75      0.75      0.75      5592

# %%
svc_model=SVC(random_state=0)
svc_model.fit(X_train,y_train)
y_pred=svc_model.predict(X_test)
from sklearn import metrics

svc_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(svc_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
svc_acc =accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.72      0.62      2810
#            1       0.59      0.41      0.48      2782
#
#     accuracy                           0.56      5592
#    macro avg       0.57      0.56      0.55      5592
# weighted avg       0.57      0.56      0.55      5592

# %%
k_range = range(1,11)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    scores.append(knn.score(X_test, y_test))

plt.xlabel('k')
plt.ylabel('accuracy')
plt.scatter(k_range, scores)
plt.vlines(k_range,0, scores, linestyle="dashed", colors='maroon')
plt.ylim(0.70,0.99)
plt.xticks([i for i in range(1,11)]);

# %%
knn_model=KNeighborsClassifier(n_neighbors = 2)
knn_model.fit(X_train,y_train)
y_pred_knn=knn_model.predict(X_test)
from sklearn import metrics

knn_cm = metrics.confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(6,5))
sns.heatmap(knn_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred_knn))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred_knn))
pred_prob_knn = gbr.predict_proba(X_test)
knn_pred_acc = accuracy_score(y_test,y_pred_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98      2810
#            1       0.96      1.00      0.98      2782
#
#     accuracy                           0.98      5592
#    macro avg       0.98      0.98      0.98      5592
# weighted avg       0.98      0.98      0.98      5592

# %%
import xgboost as xgb
XB = xgb.XGBClassifier()
XB.fit(X_train,y_train)
XB_pred = XB.score(X_test,y_test)
XB_train_accuracy = XB.score(X_train,y_train)
pred_prob_XB = XB.predict_proba(X_test)

print("Training accuracy = ",XB.score(X_train,y_train))
#Print Test Accuracy
XB_accuracy = XB.score(X_test,y_test)
print("Testing accuracy = ",XB.score(X_test,y_test))
# Out:
# Training accuracy =  0.9841738197424893
# Testing accuracy =  0.9649499284692418

# %%
XB_model=xgb.XGBClassifier()
XB_model.fit(X_train,y_train)
y_pred=XB_model.predict(X_test)
from sklearn import metrics

XB_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(XB_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
XG_BOOST = accuracy_score(y_test,y_pred)
XG_BOOST
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96      2810
#            1       0.93      1.00      0.97      2782
#
#     accuracy                           0.96      5592
#    macro avg       0.97      0.97      0.96      5592
# weighted avg       0.97      0.96      0.96      5592
# 0.9649499284692418

# %%
#2. Gaussian Naive Bayes Classifier
#t0 = time()
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()
gnb.fit(X_train,y_train)
gnb_pred = gnb.score(X_test,y_test)
gnb_train_accuracy = gnb.score(X_train,y_train)
pred_prob_gnb = gnb.predict_proba(X_test)
gnb_acc = gnb.predict(X_test)

print("Training accuracy = ",gnb.score(X_train,y_train))
#Print Test Accuracy
gnb_accuracy = gnb.score(X_test,y_test)
print("Testing accuracy = ",gnb.score(X_test,y_test))
gnb_acc2 = accuracy_score(gnb_acc,y_test)
gnb_acc2
# Out:
# Training accuracy =  0.6527181688125894
# Testing accuracy =  0.6516452074391988
# 0.6516452074391988

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob_log_reg[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob_rf[:,1], pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_test, pred_prob_gbr[:,1], pos_label=1)
fpr4, tpr4, thresh4 = roc_curve(y_test, pred_prob_knn[:,1], pos_label=1)
fpr5, tpr5, thresh5 = roc_curve(y_test, pred_prob_XB[:,1], pos_label=1)
fpr6, tpr6, thresh6 = roc_curve(y_test, pred_prob_gnb[:,1], pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, pred_prob_log_reg[:,1],multi_class='ovr')
auc_score2 = roc_auc_score(y_test, pred_prob_rf[:,1],multi_class='ovr')
auc_score3 = roc_auc_score(y_test, pred_prob_gbr[:,1],multi_class='ovr')
auc_score4 = roc_auc_score(y_test, pred_prob_knn[:,1],multi_class='ovr')
auc_score5 = roc_auc_score(y_test, pred_prob_XB[:,1],multi_class='ovr')
auc_score6 = roc_auc_score(y_test, pred_prob_gnb[:,1],multi_class='ovr')


print(auc_score1, auc_score2,auc_score3, auc_score4,auc_score5,auc_score6)
# Out:
# 0.6629920101516869 1.0 0.999776396816341 0.999776396816341 0.9951835771904286 0.6875769755238942

# %%
# plot roc curves
plt.plot(fpr1, tpr1,linestyle='--',color='orange', label='Logistic Regression')
plt.plot(fpr2, tpr2,linestyle='--',color='green', label='Random Forest')
plt.plot(fpr3, tpr3, linestyle='--',color='red', label='Gradient Boosting')
plt.plot(fpr4, tpr4, linestyle='--',color='purple', label='KNN')
plt.plot(fpr5, tpr5, linestyle='--',color='cyan', label='XGBoost')
plt.plot(fpr6, tpr6, linestyle='--',color='yellow', label='Naive Bayes')

# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();

# %%
predictions_acc = { "Model": ['Logistic Regression', 'Random Forest Classifier','Gradient Boosting Classifier', 'SVC','KNierest Neighbor','XBoost', 'Naive Bayes Classifier'],
"Accuracy": [ascore,rf_acc,gbr_accuracy,svc_acc,knn_pred_acc,XG_BOOST,gnb_acc2]}

# %%
model_acc = pd.DataFrame(predictions_acc, columns=["Model", "Accuracy"])
model_acc
# Out:
#                           Model  Accuracy
# 0           Logistic Regression  0.623748
# 1      Random Forest Classifier  0.998391
# 2  Gradient Boosting Classifier  0.991953
# 3                           SVC  0.561338
# 4             KNierest Neighbor  0.975501
# 5                        XBoost  0.964950
# 6        Naive Bayes Classifier  0.651645

# %%
Model_Name = ['Logistic Regression', 'Random Forest Classifier','Gradient Boosting Classifier', 'SVC','KNierest Neighbor','XBoost', 'Naive Bayes Classifier']
Accuracy = [ascore,rf_acc,gbr_accuracy,svc_acc,knn_pred_acc,XG_BOOST,gnb_acc2]

# %%
plt.figure(figsize=(15,9))
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Model')
sns.barplot(x = Accuracy,y = Model_Name)
plt.show()

# %%
y_test_pred = rf_model.predict(X_test)
print("Accuracy Score of Random Forest:",accuracy_score(y_test,y_test_pred))
# Out:
# Accuracy Score of Random Forest: 0.9983905579399142

# %%
output = pd.DataFrame({'Real_class': y_test, 'Predicted_class': y_test_pred, 'Difference': y_test-y_test_pred})
output.head(10)
# Out:
#        Real_class  Predicted_class  Difference
# 11886           0                0           0
# 12309           0                0           0
# 8257            0                0           0
# 13422           1                1           0
# 8998            0                0           0
# 6174            0                0           0
# 11495           0                0           0
# 13139           0                0           0
# 5359            0                0           0
# 6124            1                1           0

# %% [markdown]
# # WRAPPER METHOD USING FORWARD SELECTION

# %%
#shape of the data
df.shape
# Out:
# (14502, 42)

# %%
df.isnull().sum()
# Out:
# age_child          0
# agemos             0
# AgeGroup           0
# sex_child          0
# gastation          0
# place_delivery     0
# assistd            0
# typeofd            0
# pregtype           0
# bw_grams           0
# bw_status          0
# ethnicity          0
# age_mom            0
# agegroup_mom       0
# csc_mom            0
# psccat_mom         0
# educ_mom           0
# occup_mom          0
# work_status_mom    0
# age_hh             0
# agegroup_HH        0
# sex_hh             0
# educ_hh            0
# psoc_hh            0
# work_status_hh     0
# urbanity           0
# hhsize             0
# hhsize_code        0
# drinkingwater      0
# recipient_4ps      0
# toilet             0
# electrct1          0
# drinksafe          0
# makesafe           0
# wcooking           0
# whands             0
# collect            0
# burn               0
# composting         0
# dump               0
# segregate          0
# overweight         0
# dtype: int64

# %%
x = df.drop(['overweight'], axis=1)
y = df['overweight']

# %%
x.shape, y.shape
# Out:
# ((14502, 41), (14502,))

# %%
# importing the models

from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression

# %%
# calling the linear regression model

lreg = LinearRegression()
sfs1 = sfs(lreg, k_features=10, forward=True, verbose=2, scoring='neg_mean_squared_error')

# %%
sfs1 = sfs1.fit(X, y)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:    1.4s finished
#
# [2022-11-08 13:52:03] Features: 1/10 -- score: -0.033183728036519256[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:    0.5s finished
#
# [2022-11-08 13:52:04] Features: 2/10 -- score: -0.03294927875572794[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:    0.6s finished
#
# [2022-11-08 13:52:04] Features: 3/10 -- score: -0.03284609206042931[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:    0.5s finished
#
# [2022-11-08 13:52:05] Features: 4/10 -- score: -0.032760141693711074[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:    0.5s finished
#
# [2022-11-08 13:52:06] Features: 5/10 -- score: -0.032706520168010955[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:    0.5s finished
#
# [2022-11-08 13:52:06] Features: 6/10 -- score: -0.03265420051266517[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:    0.6s finished
#
# [2022-11-08 13:52:07] Features: 7/10 -- score: -0.032611494200573535[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    0.6s finished
#
# [2022-11-08 13:52:07] Features: 8/10 -- score: -0.03258121708650218[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.6s finished
#
# [2022-11-08 13:52:08] Features: 9/10 -- score: -0.032552010958042665[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.7s finished
#
# [2022-11-08 13:52:09] Features: 10/10 -- score: -0.03253302369209278

# %% [markdown]
# # Forward Feature Selection

# %%
feat_names = list(sfs1.k_feature_names_)
print(feat_names)
# Out:
# ['typeofd', 'bw_grams', 'psccat_mom', 'educ_mom', 'occup_mom', 'age_hh', 'educ_hh', 'drinkingwater', 'recipient_4ps', 'whands']

# %%
# creating a new dataframe using the above variables and adding the target variable
new_data = df[feat_names]
new_data['overweight'] = df['overweight']

# first five rows of the new data
new_data.head()
# Out:
# C:\Users\SUPERV~1\AppData\Local\Temp/ipykernel_17276/3046511360.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['overweight'] = df['overweight']
#    typeofd  bw_grams  psccat_mom  educ_mom  occup_mom  age_hh  educ_hh  \
# 0        1      2400           0         2         10      37        3
# 1        1      2500           2         1         10      54        2
# 2        1      2500           0         2          5      38        1
# 3        1      3200           0         2          5      36        2
# 4        1      2800           0         2         10      44        1
#
#    drinkingwater  recipient_4ps  whands  overweight
# 0              0              1       2           0
# 1              1              0       2           0
# 2              0              1       2           0
# 3              0              0       2           0
# 4              1              0       2           0

# %%
# shape of new and original data
new_data.shape, df.shape
# Out:
# ((14502, 11), (14502, 42))

# %%
new_data.head()
# Out:
#    typeofd  bw_grams  psccat_mom  educ_mom  occup_mom  age_hh  educ_hh  \
# 0        1      2400           0         2         10      37        3
# 1        1      2500           2         1         10      54        2
# 2        1      2500           0         2          5      38        1
# 3        1      3200           0         2          5      36        2
# 4        1      2800           0         2         10      44        1
#
#    drinkingwater  recipient_4ps  whands  overweight
# 0              0              1       2           0
# 1              1              0       2           0
# 2              0              1       2           0
# 3              0              0       2           0
# 4              1              0       2           0

# %%
new_data.describe()
# Out:
#             typeofd      bw_grams    psccat_mom      educ_mom     occup_mom  \
# count  14502.000000  14502.000000  14502.000000  14502.000000  14502.000000
# mean       1.114260   2975.292718      0.561854      2.082816      8.486829
# std        0.318138    598.601161      0.866355      0.685468      2.590330
# min        1.000000    900.000000      0.000000      0.000000      0.000000
# 25%        1.000000   2630.000000      0.000000      2.000000      7.000000
# 50%        1.000000   3000.000000      0.000000      2.000000     10.000000
# 75%        1.000000   3200.000000      2.000000      3.000000     10.000000
# max        2.000000   9500.000000      2.000000      4.000000     11.000000
#
#              age_hh       educ_hh  drinkingwater  recipient_4ps        whands  \
# count  14502.000000  14502.000000   14502.000000   14502.000000  14502.000000
# mean      43.175148      1.781547       0.395739       0.258447     10.929458
# std       13.358987      0.733222       0.489026       0.460519     12.845372
# min       18.000000      0.000000       0.000000       0.000000      1.000000
# 25%       33.000000      1.000000       0.000000       0.000000      1.000000
# 50%       40.000000      2.000000       0.000000       0.000000      5.000000
# 75%       52.000000      2.000000       1.000000       0.000000     13.000000
# max       96.000000      4.000000       1.000000       2.000000     91.000000
#
#          overweight
# count  14502.000000
# mean       0.034754
# std        0.183162
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14502 entries, 0 to 14501
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   typeofd        14502 non-null  int64
#  1   bw_grams       14502 non-null  int64
#  2   psccat_mom     14502 non-null  int64
#  3   educ_mom       14502 non-null  int64
#  4   occup_mom      14502 non-null  int64
#  5   age_hh         14502 non-null  int64
#  6   educ_hh        14502 non-null  int64
#  7   drinkingwater  14502 non-null  int64
#  8   recipient_4ps  14502 non-null  int64
#  9   whands         14502 non-null  int64
#  10  overweight     14502 non-null  int64
# dtypes: int64(11)
# memory usage: 1.2 MB

# %%
display("Total number of of Duplicates present in data: %s" %new_data.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 340'

# %%
new_data = new_data.drop_duplicates()
display("Total number of of Duplicates present in data: %s" %new_data.duplicated().sum())
# Out:
# 'Total number of of Duplicates present in data: 0'

# %%
#checking correlation between the variables
plt.figure(figsize=(10, 5))
sns.heatmap(new_data.corr(), annot=True);
plt.title('Correlation Matrix', fontsize=20);

# %%
final = new_data.drop(['overweight'], axis=1)
target = new_data['overweight']

# %%
final.head()
# Out:
#    typeofd  bw_grams  psccat_mom  educ_mom  occup_mom  age_hh  educ_hh  \
# 0        1      2400           0         2         10      37        3
# 1        1      2500           2         1         10      54        2
# 2        1      2500           0         2          5      38        1
# 3        1      3200           0         2          5      36        2
# 4        1      2800           0         2         10      44        1
#
#    drinkingwater  recipient_4ps  whands
# 0              0              1       2
# 1              1              0       2
# 2              0              1       2
# 3              0              0       2
# 4              1              0       2

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(final,target,test_size = 0.2, random_state=42)

# %%
Logistic = LogisticRegression()
Log_pred = Logistic.fit(X_train,y_train)
log_pred = Log_pred.predict(X_test)

ascore = accuracy_score(log_pred,y_test)
pred_prob_log_reg = Log_pred.predict_proba(X_test)

print("Training score: {:.3f}".format(Log_pred.score(X_train, y_train)))
print("Accuracy score :",ascore)
# Out:
# Training score: 0.964
# Accuracy score : 0.966113660430639
# C:\Users\Supervisor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
rforest = RandomForestClassifier(n_estimators=30, max_features=3, random_state=0)
r_pred = rforest.fit(X_train,y_train)
rf_pred = r_pred.predict(X_test)
print("Training score: {:.3f}".format(r_pred.score(X_train, y_train)))
print("Accuracy score: ",accuracy_score(rf_pred,y_test))
# Out:
# Training score: 0.998
# Accuracy score:  0.9618778679844687

# %%
rf_model=RandomForestClassifier(random_state=0)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
from sklearn import metrics

rf_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(rf_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2737
#            1       0.00      0.00      0.00        96
#
#     accuracy                           0.96      2833
#    macro avg       0.48      0.50      0.49      2833
# weighted avg       0.93      0.96      0.95      2833

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14162 entries, 0 to 14501
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   typeofd        14162 non-null  int64
#  1   bw_grams       14162 non-null  int64
#  2   psccat_mom     14162 non-null  int64
#  3   educ_mom       14162 non-null  int64
#  4   occup_mom      14162 non-null  int64
#  5   age_hh         14162 non-null  int64
#  6   educ_hh        14162 non-null  int64
#  7   drinkingwater  14162 non-null  int64
#  8   recipient_4ps  14162 non-null  int64
#  9   whands         14162 non-null  int64
#  10  overweight     14162 non-null  int64
# dtypes: int64(11)
# memory usage: 1.3 MB

# %%
new_data.shape
# Out:
# (14162, 11)

# %%
from sklearn.utils import resample

# Separate Target Classes
df_1 = new_data[new_data.overweight==0]
df_2 = new_data[new_data.overweight==1]
 
# Upsample minority class
df_2_upsampled4 = resample(df_2, 
                                 replace=True,     # sample with replacement
                                 n_samples=14162,    # to match majority class
                                 random_state=123) # reproducible results

# Combine majority class with upsampled minority class
df_upsampled5 = pd.concat([df_1, df_2_upsampled4])
 
# Display new class counts
df_upsampled5.overweight.value_counts()
df_upsampled5.reset_index(drop=True)
# Out:
#        typeofd  bw_grams  psccat_mom  educ_mom  occup_mom  age_hh  educ_hh  \
# 0            1      2400           0         2         10      37        3
# 1            1      2500           2         1         10      54        2
# 2            1      2500           0         2          5      38        1
# 3            1      3200           0         2          5      36        2
# 4            1      2800           0         2         10      44        1
# ...        ...       ...         ...       ...        ...     ...      ...
# 27817        1      3000           0         1         10      51        3
# 27818        1      2900           0         2          5      72        1
# 27819        1      2272           0         3         11      41        2
# 27820        2      2900           0         3          5      37        2
# 27821        1      3147           0         2         10      48        1
#
#        drinkingwater  recipient_4ps  whands  overweight
# 0                  0              1       2           0
# 1                  1              0       2           0
# 2                  0              1       2           0
# 3                  0              0       2           0
# 4                  1              0       2           0
# ...              ...            ...     ...         ...
# 27817              0              1       3           1
# 27818              1              0       1           1
# 27819              0              0       1           1
# 27820              1              0       2           1
# 27821              1              1      11           1
#
# [27822 rows x 11 columns]

# %%
df_upsampled5.shape
# Out:
# (27822, 11)

# %%
df_upsampled5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27822 entries, 0 to 12317
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   typeofd        27822 non-null  int64
#  1   bw_grams       27822 non-null  int64
#  2   psccat_mom     27822 non-null  int64
#  3   educ_mom       27822 non-null  int64
#  4   occup_mom      27822 non-null  int64
#  5   age_hh         27822 non-null  int64
#  6   educ_hh        27822 non-null  int64
#  7   drinkingwater  27822 non-null  int64
#  8   recipient_4ps  27822 non-null  int64
#  9   whands         27822 non-null  int64
#  10  overweight     27822 non-null  int64
# dtypes: int64(11)
# memory usage: 2.5 MB

# %%
df_upsampled5.columns
# Out:
# Index(['typeofd', 'bw_grams', 'psccat_mom', 'educ_mom', 'occup_mom', 'age_hh',
#        'educ_hh', 'drinkingwater', 'recipient_4ps', 'whands', 'overweight'],
#       dtype='object')

# %%
final1 = df_upsampled5.drop(['overweight'],axis=1)
target1 = df_upsampled5['overweight']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(final1,target1,test_size = 0.2, random_state=42)

# %%
Logistic = LogisticRegression()
Log_pred = Logistic.fit(X_train,y_train)
log_pred = Log_pred.predict(X_test)

ascore = accuracy_score(log_pred,y_test)
pred_prob_log_reg = Log_pred.predict_proba(X_test)

print("Training score: {:.3f}".format(Log_pred.score(X_train, y_train)))
print("Accuracy score :",ascore)
# Out:
# Training score: 0.682
# Accuracy score : 0.6885893980233603

# %%
rforest = RandomForestClassifier(n_estimators=30, max_features=3, random_state=0)
r_pred = rforest.fit(X_train,y_train)
rf_pred = r_pred.predict(X_test)
print("Training score: {:.3f}".format(r_pred.score(X_train, y_train)))
print("Accuracy score: ",accuracy_score(rf_pred,y_test))

pred_prob_rf = r_pred.predict_proba(X_test)
# Out:
# Training score: 1.000
# Accuracy score:  0.9926325247079965

# %%
rf_model=RandomForestClassifier(random_state=0)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
from sklearn import metrics

rf_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(rf_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
rf_acc = accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2745
#            1       0.99      1.00      0.99      2820
#
#     accuracy                           0.99      5565
#    macro avg       0.99      0.99      0.99      5565
# weighted avg       0.99      0.99      0.99      5565

# %%
gbr = GradientBoostingClassifier(n_estimators=100, max_depth=10, max_features=3, random_state=0).fit(X_train, y_train)
gbr_pred= gbr.score(X_test, y_test)

gbr_train_accuracy =gbr.score(X_train,y_train)
gbr_accuracy = gbr.score(X_test,y_test)
pred_prob_gbr = gbr.predict_proba(X_test)


print("Training score: {:.3f}".format(gbr.score(X_train, y_train)))
print("Test score: {:.3f}".format(gbr.score(X_test, y_test)))
# Out:
# Training score: 0.992
# Test score: 0.982

# %%
gbr_model=GradientBoostingClassifier(random_state=0)
gbr_test = gbr_model.fit(X_train,y_train)
y_pred_gbr=gbr_test.predict(X_test)
from sklearn import metrics
gbr_pred_randomstate= gbr.score(X_test, y_test)

gbr_cm = metrics.confusion_matrix(y_test, y_pred_gbr)
plt.figure(figsize=(6,5))
sns.heatmap(gbr_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred_gbr))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred_gbr))
gbr_acc=accuracy_score(y_test,y_pred_gbr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75      2745
#            1       0.75      0.81      0.78      2820
#
#     accuracy                           0.76      5565
#    macro avg       0.77      0.76      0.76      5565
# weighted avg       0.77      0.76      0.76      5565

# %%
svc_model=SVC(random_state=0)
svc_model.fit(X_train,y_train)
y_pred=svc_model.predict(X_test)
from sklearn import metrics

svc_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(svc_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
svc_acc =accuracy_score(y_test,y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.62      0.58      2745
#            1       0.57      0.50      0.54      2820
#
#     accuracy                           0.56      5565
#    macro avg       0.56      0.56      0.56      5565
# weighted avg       0.56      0.56      0.56      5565

# %%
k_range = range(1,11)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    scores.append(knn.score(X_test, y_test))

plt.xlabel('k')
plt.ylabel('accuracy')
plt.scatter(k_range, scores)
plt.vlines(k_range,0, scores, linestyle="dashed", colors='maroon')
plt.ylim(0.70,0.99)
plt.xticks([i for i in range(1,11)]);

# %%
knn_model=KNeighborsClassifier(n_neighbors = 2)
knn_model.fit(X_train,y_train)
y_pred_knn=knn_model.predict(X_test)
from sklearn import metrics

knn_cm = metrics.confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(6,5))
sns.heatmap(knn_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred_knn))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred_knn))
pred_prob_knn = gbr.predict_proba(X_test)
knn_pred_acc = accuracy_score(y_test,y_pred_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      2745
#            1       0.96      1.00      0.98      2820
#
#     accuracy                           0.98      5565
#    macro avg       0.98      0.98      0.98      5565
# weighted avg       0.98      0.98      0.98      5565

# %%
import xgboost as xgb
XB = xgb.XGBClassifier()
XB.fit(X_train,y_train)
XB_pred = XB.score(X_test,y_test)
XB_train_accuracy = XB.score(X_train,y_train)
pred_prob_XB = XB.predict_proba(X_test)

print("Training accuracy = ",XB.score(X_train,y_train))
#Print Test Accuracy
XB_accuracy = XB.score(X_test,y_test)
print("Testing accuracy = ",XB.score(X_test,y_test))
# Out:
# Training accuracy =  0.9579907444848812
# Testing accuracy =  0.9464510332434861

# %%
XB_model=xgb.XGBClassifier()
XB_model.fit(X_train,y_train)
y_pred=XB_model.predict(X_test)
from sklearn import metrics

XB_cm = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(XB_cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(metrics.accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()
print(metrics.classification_report(y_test,y_pred))
XG_BOOST = accuracy_score(y_test,y_pred)
XG_BOOST
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.94      2745
#            1       0.91      1.00      0.95      2820
#
#     accuracy                           0.95      5565
#    macro avg       0.95      0.95      0.95      5565
# weighted avg       0.95      0.95      0.95      5565
# 0.9464510332434861

# %%
#2. Gaussian Naive Bayes Classifier
#t0 = time()
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()
gnb.fit(X_train,y_train)
gnb_pred = gnb.score(X_test,y_test)
gnb_train_accuracy = gnb.score(X_train,y_train)
pred_prob_gnb = gnb.predict_proba(X_test)
gnb_acc = gnb.predict(X_test)

print("Training accuracy = ",gnb.score(X_train,y_train))
#Print Test Accuracy
gnb_accuracy = gnb.score(X_test,y_test)
print("Testing accuracy = ",gnb.score(X_test,y_test))
# Out:
# Training accuracy =  0.6906141887945365
# Testing accuracy =  0.6954177897574124

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob_log_reg[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob_rf[:,1], pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_test, pred_prob_gbr[:,1], pos_label=1)
fpr4, tpr4, thresh4 = roc_curve(y_test, pred_prob_knn[:,1], pos_label=1)
fpr5, tpr5, thresh5 = roc_curve(y_test, pred_prob_XB[:,1], pos_label=1)
fpr6, tpr6, thresh6 = roc_curve(y_test, pred_prob_gnb[:,1], pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)


from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, pred_prob_log_reg[:,1],multi_class='ovr')
auc_score2 = roc_auc_score(y_test, pred_prob_rf[:,1],multi_class='ovr')
auc_score3 = roc_auc_score(y_test, pred_prob_gbr[:,1],multi_class='ovr')
auc_score4 = roc_auc_score(y_test, pred_prob_knn[:,1],multi_class='ovr')
auc_score5 = roc_auc_score(y_test, pred_prob_XB[:,1],multi_class='ovr')
auc_score6 = roc_auc_score(y_test, pred_prob_gnb[:,1],multi_class='ovr')


print(auc_score1, auc_score2,auc_score3, auc_score4,auc_score5,auc_score6)
# Out:
# 0.7434408789675618 0.999427908899482 0.9992244441860765 0.9992244441860765 0.9868102546215557 0.7526244364350398

# %%
# plot roc curves
plt.plot(fpr1, tpr1,linestyle='--',color='orange', label='Logistic Regression')
plt.plot(fpr2, tpr2,linestyle='--',color='green', label='Random Forest')
plt.plot(fpr3, tpr3, linestyle='--',color='red', label='Gradient Boosting')
plt.plot(fpr4, tpr4, linestyle='--',color='purple', label='KNN')
plt.plot(fpr5, tpr5, linestyle='--',color='cyan', label='XGBoost')
plt.plot(fpr6, tpr6, linestyle='--',color='yellow', label='Naive Bayes')

# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();

# %%
predictions_acc = { "Model": ['Logistic Regression', 'Random Forest Classifier','Gradient Boosting Classifier', 'SVC','KNierest Neighbor','XBoost', 'Naive Bayes Classifier'],
"Accuracy": [ascore,rf_acc,gbr_accuracy,svc_acc,knn_pred_acc,XG_BOOST,gnb_acc2]}

# %%
model_acc = pd.DataFrame(predictions_acc, columns=["Model", "Accuracy"])
model_acc
# Out:
#                           Model  Accuracy
# 0           Logistic Regression  0.688589
# 1      Random Forest Classifier  0.993172
# 2  Gradient Boosting Classifier  0.982210
# 3                           SVC  0.559389
# 4             KNierest Neighbor  0.975741
# 5                        XBoost  0.946451
# 6        Naive Bayes Classifier  0.651645

# %%
Model_Name = ['Logistic Regression', 'Random Forest Classifier','Gradient Boosting Classifier', 'SVC','KNierest Neighbor','XBoost', 'Naive Bayes Classifier']
Accuracy = [ascore,rf_acc,gbr_accuracy,svc_acc,knn_pred_acc,XG_BOOST,gnb_acc2]

# %%
plt.figure(figsize=(15,9))
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Model')
sns.barplot(x = Accuracy,y = Model_Name)
plt.show()

# %%
y_test_pred = rf_model.predict(X_test)
print("Accuracy Score of Random Forest:",accuracy_score(y_test,y_test_pred))
# Out:
# Accuracy Score of Random Forest: 0.9931716082659479

# %%
output = pd.DataFrame({'Real_class': y_test, 'Predicted_class': y_test_pred, 'Difference': y_test-y_test_pred})
output.head(10)
# Out:
#        Real_class  Predicted_class  Difference
# 10265           0                0           0
# 370             1                1           0
# 7864            0                0           0
# 8000            0                0           0
# 6683            0                0           0
# 12192           1                1           0
# 1171            0                0           0
# 5507            1                1           0
# 6415            1                1           0
# 10296           0                0           0

# %% [markdown]
# # FINAL FEATURES AND FITTING IT INTO THE MODEL
